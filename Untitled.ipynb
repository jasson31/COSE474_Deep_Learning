# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T


env = gym.make('CartPole-v0').unwrapped

# matplotlib 설정
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# GPU를 사용할 경우
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """transition 저장"""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class DQN(nn.Module):

    def __init__(self, h, w, outputs):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=5, stride=2)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, stride=2)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=2)
        self.bn3 = nn.BatchNorm2d(32)

        # Linear 입력의 연결 숫자는 conv2d 계층의 출력과 입력 이미지의 크기에
        # 따라 결정되기 때문에 따로 계산을 해야합니다.
        def conv2d_size_out(size, kernel_size = 5, stride = 2):
            return (size - (kernel_size - 1) - 1) // stride  + 1
        convw = conv2d_size_out(conv2d_size_out(conv2d_size_out(w)))
        convh = conv2d_size_out(conv2d_size_out(conv2d_size_out(h)))
        linear_input_size = convw * convh * 32
        self.head = nn.Linear(linear_input_size, outputs)

    # 최적화 중에 다음 행동을 결정하기 위해서 하나의 요소 또는 배치를 이용해 호촐됩니다.
    # ([[left0exp,right0exp]...]) 를 반환합니다.
    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        return self.head(x.view(x.size(0), -1))

# %%
resize = T.Compose([T.ToPILImage(),
                    T.Resize(40, interpolation=Image.CUBIC),
                    T.ToTensor()])


def get_cart_location(screen_width):
    world_width = env.x_threshold * 2
    scale = screen_width / world_width
    return int(env.state[0] * scale + screen_width / 2.0)  # MIDDLE OF CART

def get_screen():
    # gym이 요청한 화면은 400x600x3 이지만, 가끔 800x1200x3 처럼 큰 경우가 있습니다.
    # 이것을 Torch order (CHW)로 변환한다.
    screen = env.render(mode='rgb_array').transpose((2, 0, 1))
    # 카트는 아래쪽에 있으므로 화면의 상단과 하단을 제거하십시오.
    _, screen_height, screen_width = screen.shape
    screen = screen[:, int(screen_height*0.4):int(screen_height * 0.8)]
    view_width = int(screen_width * 0.6)
    cart_location = get_cart_location(screen_width)
    if cart_location < view_width // 2:
        slice_range = slice(view_width)
    elif cart_location > (screen_width - view_width // 2):
        slice_range = slice(-view_width, None)
    else:
        slice_range = slice(cart_location - view_width // 2,
                            cart_location + view_width // 2)
    # 카트를 중심으로 정사각형 이미지가 되도록 가장자리를 제거하십시오.
    screen = screen[:, :, slice_range]
    # float 으로 변환하고,  rescale 하고, torch tensor 로 변환하십시오.
    # (이것은 복사를 필요로하지 않습니다)
    screen = np.ascontiguousarray(screen, dtype=np.float32) / 255
    screen = torch.from_numpy(screen)
    # 크기를 수정하고 배치 차원(BCHW)을 추가하십시오.
    return resize(screen).unsqueeze(0).to(device)


env.reset()
plt.figure()
plt.imshow(get_screen().cpu().squeeze(0).permute(1, 2, 0).numpy(),
           interpolation='none')
plt.title('Example extracted screen')
plt.show()

# %%
BATCH_SIZE = 128
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10

# AI gym에서 반환된 형태를 기반으로 계층을 초기화 하도록 화면의 크기를
# 가져옵니다. 이 시점에 일반적으로 3x40x90 에 가깝습니다.
# 이 크기는 get_screen()에서 고정, 축소된 렌더 버퍼의 결과입니다.
init_screen = get_screen()
_, _, screen_height, screen_width = init_screen.shape

# gym 행동 공간에서 행동의 숫자를 얻습니다.
n_actions = env.action_space.n

policy_net = DQN(screen_height, screen_width, n_actions).to(device)
target_net = DQN(screen_height, screen_width, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.RMSprop(policy_net.parameters())
memory = ReplayMemory(10000)


steps_done = 0


def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max (1)은 각 행의 가장 큰 열 값을 반환합니다.
            # 최대 결과의 두번째 열은 최대 요소의 주소값이므로,
            # 기대 보상이 더 큰 행동을 선택할 수 있습니다.
            print(policy_net(state));
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(n_actions)]], device=device, dtype=torch.long)


episode_durations = []


def plot_durations():
    plt.figure(2)
    plt.clf()
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # 100개의 에피소드 평균을 가져 와서 도표 그리기
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # 도표가 업데이트되도록 잠시 멈춤
    if is_ipython:
        display.clear_output(wait=True)
        display.display(plt.gcf())

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). 이것은 batch-array의 Transitions을 Transition의 batch-arrays로
    # 전환합니다.
    batch = Transition(*zip(*transitions))

    # 최종이 아닌 상태의 마스크를 계산하고 배치 요소를 연결합니다
    # (최종 상태는 시뮬레이션이 종료 된 이후의 상태)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Q(s_t, a) 계산 - 모델이 Q(s_t)를 계산하고, 취한 행동의 열을 선택합니다.
    # 이들은 policy_net에 따라 각 배치 상태에 대해 선택된 행동입니다.
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # 모든 다음 상태를 위한 V(s_{t+1}) 계산
    # non_final_next_states의 행동들에 대한 기대값은 "이전" target_net을 기반으로 계산됩니다.
    # max(1)[0]으로 최고의 보상을 선택하십시오.
    # 이것은 마스크를 기반으로 병합되어 기대 상태 값을 갖거나 상태가 최종인 경우 0을 갖습니다.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # 기대 Q 값 계산
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Huber 손실 계산
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # 모델 최적화
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
num_episodes = 50
for i_episode in range(num_episodes):
    # 환경과 상태 초기화
    env.reset()
    last_screen = get_screen()
    current_screen = get_screen()
    state = current_screen - last_screen
    for t in count():
        # 행동 선택과 수행
        action = select_action(state)
        _, reward, done, _ = env.step(action.item())
        reward = torch.tensor([reward], device=device)

        # 새로운 상태 관찰
        last_screen = current_screen
        current_screen = get_screen()
        if not done:
            next_state = current_screen - last_screen
        else:
            next_state = None

        # 메모리에 변이 저장
        memory.push(state, action, next_state, reward)

        # 다음 상태로 이동
        state = next_state

        # 최적화 한단계 수행(목표 네트워크에서)
        optimize_model()
        if done:
            episode_durations.append(t + 1)
            #plot_durations()
            break
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.render()
env.close()
plt.ioff()
plt.show()
# Out:
# tensor([[0.0999, 0.7394]], device='cuda:0')
# tensor([[0.3300, 0.1058]], device='cuda:0')
# tensor([[0.8331, 0.0044]], device='cuda:0')
# tensor([[ 0.6230, -0.7612]], device='cuda:0')
# tensor([[0.0127, 0.0334]], device='cuda:0')
# tensor([[-0.4837,  0.2228]], device='cuda:0')
# tensor([[0.2712, 0.5148]], device='cuda:0')
# tensor([[0.0131, 0.0853]], device='cuda:0')
# tensor([[-0.3109,  0.5057]], device='cuda:0')
# tensor([[-0.0182,  0.3173]], device='cuda:0')
# tensor([[0.2334, 0.1743]], device='cuda:0')
# tensor([[0.5537, 0.7251]], device='cuda:0')
# tensor([[0.7023, 0.3998]], device='cuda:0')
# tensor([[ 0.7267, -0.2536]], device='cuda:0')
# tensor([[ 0.1791, -0.3915]], device='cuda:0')
# tensor([[0.0713, 0.7282]], device='cuda:0')
# tensor([[0.5275, 0.4018]], device='cuda:0')
# tensor([[0.4490, 0.4143]], device='cuda:0')
# tensor([[-0.1821,  0.3728]], device='cuda:0')
# tensor([[0.0573, 0.2856]], device='cuda:0')
# tensor([[0.3784, 0.3957]], device='cuda:0')
# tensor([[0.1887, 0.1146]], device='cuda:0')
# tensor([[0.0301, 0.0159]], device='cuda:0')
# tensor([[ 0.3476, -0.0774]], device='cuda:0')
# tensor([[ 0.5149, -0.7087]], device='cuda:0')
# tensor([[-0.1013,  0.0165]], device='cuda:0')
# tensor([[0.0301, 0.0159]], device='cuda:0')
# tensor([[ 0.2071, -0.3162]], device='cuda:0')
# tensor([[ 0.3008, -0.1288]], device='cuda:0')
# tensor([[ 0.3734, -0.1512]], device='cuda:0')
# tensor([[ 0.5341, -0.9164]], device='cuda:0')
# tensor([[ 0.5584, -0.8792]], device='cuda:0')
# tensor([[-0.3227,  0.2858]], device='cuda:0')
# tensor([[0.3503, 0.5036]], device='cuda:0')
# tensor([[ 0.1927, -0.1703]], device='cuda:0')
# tensor([[0.2956, 0.1489]], device='cuda:0')
# tensor([[ 0.3717, -0.0284]], device='cuda:0')
# tensor([[ 0.3673, -0.4183]], device='cuda:0')
# tensor([[0.0757, 0.5781]], device='cuda:0')
# tensor([[ 0.4974, -0.5197]], device='cuda:0')
# tensor([[ 0.2466, -0.4372]], device='cuda:0')
# tensor([[ 0.6064, -0.0459]], device='cuda:0')
# tensor([[ 0.3458, -0.3327]], device='cuda:0')
# tensor([[-0.0528, -0.0863]], device='cuda:0')
# tensor([[0.0301, 0.0159]], device='cuda:0')
# tensor([[0.4380, 0.0942]], device='cuda:0')
# tensor([[ 0.3105, -0.0312]], device='cuda:0')
# tensor([[0.1086, 0.3641]], device='cuda:0')
# tensor([[19.8222, 19.3317]], device='cuda:0')
# tensor([[1.2588, 1.2134]], device='cuda:0')
# tensor([[-1.6081, -4.5399]], device='cuda:0')
# tensor([[2.6734, 2.7566]], device='cuda:0')
# tensor([[0.0407, 0.0516]], device='cuda:0')
# tensor([[2.0211, 1.6816]], device='cuda:0')
# tensor([[1.8841, 1.3350]], device='cuda:0')
# tensor([[2.4814, 2.1302]], device='cuda:0')
# tensor([[1.3041, 0.7075]], device='cuda:0')
# tensor([[2.0276, 2.3005]], device='cuda:0')
# tensor([[0.8945, 0.9818]], device='cuda:0')
# tensor([[0.1102, 0.1221]], device='cuda:0')
# tensor([[2.2436, 2.5489]], device='cuda:0')
# tensor([[1.4156, 1.2665]], device='cuda:0')
# tensor([[2.5761, 1.9682]], device='cuda:0')
# tensor([[1.4958, 1.6376]], device='cuda:0')
# tensor([[1.9492, 1.6198]], device='cuda:0')
# tensor([[1.7377, 1.9265]], device='cuda:0')
# tensor([[2.0275, 1.9082]], device='cuda:0')
# tensor([[1.5733, 1.6065]], device='cuda:0')
# tensor([[1.7616, 1.5935]], device='cuda:0')
# tensor([[1.8045, 1.7306]], device='cuda:0')
# tensor([[1.5599, 1.6671]], device='cuda:0')
# tensor([[1.8538, 1.7013]], device='cuda:0')
# tensor([[1.5296, 1.3623]], device='cuda:0')
# tensor([[3.0482, 2.6659]], device='cuda:0')
# tensor([[1.6149, 1.6421]], device='cuda:0')
# tensor([[1.5618, 1.8709]], device='cuda:0')
# tensor([[3.0713, 2.7074]], device='cuda:0')
# tensor([[2.6571, 2.2707]], device='cuda:0')
# tensor([[1.7585, 1.7095]], device='cuda:0')
# tensor([[1.4652, 1.8157]], device='cuda:0')
# tensor([[3.1507, 2.2680]], device='cuda:0')
# tensor([[2.3839, 1.9972]], device='cuda:0')
# tensor([[2.6834, 1.8789]], device='cuda:0')
# tensor([[1.5376, 1.6583]], device='cuda:0')
# tensor([[1.9059, 1.8133]], device='cuda:0')
# tensor([[1.6642, 2.0362]], device='cuda:0')
# tensor([[2.1965, 2.2753]], device='cuda:0')
# tensor([[1.6831, 1.7250]], device='cuda:0')
# tensor([[2.2311, 1.9274]], device='cuda:0')
# tensor([[2.8823, 2.2405]], device='cuda:0')
# tensor([[2.1395, 1.8338]], device='cuda:0')
# tensor([[1.9574, 1.8944]], device='cuda:0')
# tensor([[1.7213, 1.8940]], device='cuda:0')
# tensor([[1.5933, 1.9639]], device='cuda:0')
# tensor([[2.7551, 2.0807]], device='cuda:0')
# tensor([[2.0756, 1.9654]], device='cuda:0')
# tensor([[1.7859, 1.8558]], device='cuda:0')
# tensor([[1.3787, 1.9084]], device='cuda:0')
# tensor([[1.8831, 1.9875]], device='cuda:0')
# tensor([[1.9078, 2.0745]], device='cuda:0')
# tensor([[1.7689, 1.7850]], device='cuda:0')
# tensor([[1.9908, 2.3960]], device='cuda:0')
# tensor([[0.1159, 0.1313]], device='cuda:0')
# tensor([[2.5044, 3.0843]], device='cuda:0')
# tensor([[3.0997, 3.2486]], device='cuda:0')
# tensor([[4.1104, 3.4448]], device='cuda:0')
# tensor([[5.5501, 5.3368]], device='cuda:0')
# tensor([[4.1957, 4.0752]], device='cuda:0')
# tensor([[3.4399, 3.4979]], device='cuda:0')
# tensor([[2.3487, 2.4725]], device='cuda:0')
# tensor([[4.4444, 4.4902]], device='cuda:0')
# tensor([[4.9980, 4.2885]], device='cuda:0')
# tensor([[5.2084, 4.5101]], device='cuda:0')
# tensor([[4.0540, 3.9199]], device='cuda:0')
# tensor([[4.6378, 4.4523]], device='cuda:0')
# tensor([[2.9609, 3.0298]], device='cuda:0')
# tensor([[3.7934, 3.9423]], device='cuda:0')
# tensor([[3.7559, 3.9771]], device='cuda:0')
# tensor([[2.8238, 3.0477]], device='cuda:0')
# tensor([[3.7540, 3.4638]], device='cuda:0')
# tensor([[4.0352, 3.6898]], device='cuda:0')
# tensor([[3.0032, 3.1601]], device='cuda:0')
# tensor([[2.5458, 2.9318]], device='cuda:0')
# tensor([[3.3256, 3.7776]], device='cuda:0')
# tensor([[4.2789, 4.2281]], device='cuda:0')
# tensor([[3.0837, 3.6759]], device='cuda:0')
# tensor([[4.3931, 4.4208]], device='cuda:0')
# tensor([[3.8138, 4.1613]], device='cuda:0')
# tensor([[3.3311, 3.2441]], device='cuda:0')
# tensor([[3.6989, 4.1309]], device='cuda:0')
# tensor([[3.1634, 3.2547]], device='cuda:0')
# tensor([[4.1167, 3.9071]], device='cuda:0')
# tensor([[4.5313, 4.7013]], device='cuda:0')
# tensor([[3.4080, 3.7020]], device='cuda:0')
# tensor([[3.8446, 4.2502]], device='cuda:0')
# tensor([[3.3853, 3.7732]], device='cuda:0')
# tensor([[4.4181, 4.3814]], device='cuda:0')
# tensor([[2.7522, 2.5737]], device='cuda:0')
# tensor([[3.7044, 3.5905]], device='cuda:0')
# tensor([[2.4975, 2.6551]], device='cuda:0')
# tensor([[3.6554, 3.5960]], device='cuda:0')
# tensor([[3.4932, 3.4912]], device='cuda:0')
# tensor([[3.1276, 3.4128]], device='cuda:0')
# tensor([[0.4593, 0.4293]], device='cuda:0')
# tensor([[3.0956, 3.3460]], device='cuda:0')
# tensor([[2.9876, 3.2124]], device='cuda:0')
# tensor([[3.9528, 4.2319]], device='cuda:0')
# tensor([[3.0103, 3.0514]], device='cuda:0')
# tensor([[3.8791, 3.7257]], device='cuda:0')
# tensor([[4.5842, 4.6173]], device='cuda:0')
# tensor([[3.4755, 3.5391]], device='cuda:0')
# tensor([[3.5849, 3.6389]], device='cuda:0')
# tensor([[3.1604, 3.2640]], device='cuda:0')
# tensor([[3.4998, 3.6610]], device='cuda:0')
# tensor([[0.4952, 0.4769]], device='cuda:0')
# tensor([[3.1932, 2.7832]], device='cuda:0')
# tensor([[3.9021, 3.8749]], device='cuda:0')
# tensor([[3.8784, 4.1653]], device='cuda:0')
# tensor([[3.5774, 3.6555]], device='cuda:0')
# tensor([[2.9673, 3.0901]], device='cuda:0')
# tensor([[3.2057, 3.6210]], device='cuda:0')
# tensor([[3.1146, 3.5678]], device='cuda:0')
# tensor([[3.1309, 2.9007]], device='cuda:0')
# tensor([[3.3941, 3.8171]], device='cuda:0')
# tensor([[3.1959, 3.1147]], device='cuda:0')
# tensor([[2.9911, 3.2821]], device='cuda:0')
# tensor([[0.5035, 0.4848]], device='cuda:0')
# tensor([[3.4374, 3.2683]], device='cuda:0')
# tensor([[3.6808, 3.8817]], device='cuda:0')
# tensor([[3.2879, 3.4235]], device='cuda:0')
# tensor([[3.0498, 3.1593]], device='cuda:0')
# tensor([[4.1829, 4.1301]], device='cuda:0')
# tensor([[3.1599, 3.4004]], device='cuda:0')
# tensor([[3.0033, 3.2169]], device='cuda:0')
# tensor([[4.1030, 3.7850]], device='cuda:0')
# tensor([[3.0941, 3.2503]], device='cuda:0')
# tensor([[3.0826, 2.8692]], device='cuda:0')
# tensor([[4.5707, 4.5186]], device='cuda:0')
# tensor([[3.0826, 3.4645]], device='cuda:0')
# tensor([[4.1296, 4.1247]], device='cuda:0')
# tensor([[4.2141, 4.1614]], device='cuda:0')
# tensor([[4.0803, 4.0418]], device='cuda:0')
# tensor([[3.6713, 3.5314]], device='cuda:0')
# tensor([[3.5282, 3.6692]], device='cuda:0')
# tensor([[2.8833, 2.7866]], device='cuda:0')
# tensor([[2.9819, 3.3389]], device='cuda:0')
# tensor([[0.4574, 0.4591]], device='cuda:0')
# tensor([[3.8613, 3.8224]], device='cuda:0')
# tensor([[4.4547, 4.3879]], device='cuda:0')
# tensor([[3.2357, 2.7857]], device='cuda:0')
# tensor([[4.2540, 4.2258]], device='cuda:0')
# tensor([[3.7548, 4.0380]], device='cuda:0')
# tensor([[3.2060, 3.2958]], device='cuda:0')
# tensor([[3.5381, 3.9641]], device='cuda:0')
# tensor([[4.4943, 4.3155]], device='cuda:0')
# tensor([[3.2470, 2.9160]], device='cuda:0')
# tensor([[4.4501, 4.4414]], device='cuda:0')
# tensor([[3.4912, 3.6194]], device='cuda:0')
# tensor([[2.9824, 3.0922]], device='cuda:0')
# tensor([[3.6894, 3.9652]], device='cuda:0')
# tensor([[3.0174, 3.2283]], device='cuda:0')
# tensor([[4.4094, 4.3669]], device='cuda:0')
# tensor([[4.6348, 4.4714]], device='cuda:0')
# tensor([[4.4523, 4.2389]], device='cuda:0')
# tensor([[3.2860, 3.6445]], device='cuda:0')
# tensor([[3.4889, 3.7866]], device='cuda:0')
# tensor([[3.1644, 3.4757]], device='cuda:0')
# tensor([[4.6684, 4.3887]], device='cuda:0')
# tensor([[4.1334, 3.9845]], device='cuda:0')
# tensor([[3.5707, 3.7212]], device='cuda:0')
# tensor([[2.6979, 3.0000]], device='cuda:0')
# tensor([[3.8099, 3.7167]], device='cuda:0')
# tensor([[2.9640, 3.1792]], device='cuda:0')
# tensor([[3.5272, 3.6530]], device='cuda:0')
# tensor([[3.2592, 3.2764]], device='cuda:0')
# tensor([[0.4562, 0.4492]], device='cuda:0')
# tensor([[3.9462, 4.1536]], device='cuda:0')
# tensor([[2.2054, 2.4109]], device='cuda:0')
# tensor([[3.4012, 3.5596]], device='cuda:0')
# tensor([[3.8309, 3.5621]], device='cuda:0')
# tensor([[3.5567, 3.8589]], device='cuda:0')
# tensor([[3.3501, 3.7848]], device='cuda:0')
# tensor([[3.6505, 4.0653]], device='cuda:0')
# tensor([[3.8226, 4.0760]], device='cuda:0')
# tensor([[3.5256, 3.4520]], device='cuda:0')
# tensor([[2.9735, 3.2468]], device='cuda:0')
# tensor([[3.9094, 3.9335]], device='cuda:0')
# tensor([[2.3786, 2.5670]], device='cuda:0')
# tensor([[0.6323, 0.6003]], device='cuda:0')
# tensor([[3.8930, 3.9141]], device='cuda:0')
# tensor([[3.4228, 3.5476]], device='cuda:0')
# tensor([[3.0525, 3.4160]], device='cuda:0')
# tensor([[3.4012, 3.2429]], device='cuda:0')
# tensor([[3.6883, 3.9936]], device='cuda:0')
# tensor([[3.6335, 3.8474]], device='cuda:0')
# tensor([[3.4409, 3.9096]], device='cuda:0')
# tensor([[3.8119, 4.0265]], device='cuda:0')
# tensor([[2.9216, 2.8935]], device='cuda:0')
# tensor([[3.4017, 3.4090]], device='cuda:0')
# tensor([[3.3459, 3.4677]], device='cuda:0')
# tensor([[3.4216, 3.4788]], device='cuda:0')
# tensor([[2.6889, 3.0261]], device='cuda:0')
# tensor([[0.6485, 0.6301]], device='cuda:0')
# tensor([[3.0303, 3.1782]], device='cuda:0')
# tensor([[3.7829, 3.8907]], device='cuda:0')
# tensor([[3.1028, 3.0814]], device='cuda:0')
# tensor([[2.9226, 3.1140]], device='cuda:0')
# tensor([[4.3562, 4.3561]], device='cuda:0')
# tensor([[2.7897, 2.7607]], device='cuda:0')
# tensor([[3.9247, 4.1811]], device='cuda:0')
# tensor([[3.2096, 3.4729]], device='cuda:0')
# tensor([[3.2465, 3.2419]], device='cuda:0')
# tensor([[3.2090, 3.5117]], device='cuda:0')
# tensor([[3.3541, 3.8146]], device='cuda:0')
# tensor([[3.4066, 3.6375]], device='cuda:0')
# tensor([[3.3377, 3.7247]], device='cuda:0')
# tensor([[3.2713, 3.6848]], device='cuda:0')
# tensor([[3.5815, 3.7546]], device='cuda:0')
# tensor([[3.9679, 4.3925]], device='cuda:0')
# tensor([[3.3901, 3.5377]], device='cuda:0')
# tensor([[3.0389, 2.7566]], device='cuda:0')
# tensor([[3.8249, 3.8268]], device='cuda:0')
# tensor([[3.5853, 3.3996]], device='cuda:0')
# tensor([[3.7951, 3.6271]], device='cuda:0')
# tensor([[3.8350, 4.1899]], device='cuda:0')
# tensor([[3.0539, 3.2624]], device='cuda:0')
# tensor([[3.3627, 3.5795]], device='cuda:0')
# tensor([[3.4467, 3.6161]], device='cuda:0')
# tensor([[3.6910, 4.1014]], device='cuda:0')
# tensor([[2.9693, 3.3979]], device='cuda:0')
# tensor([[2.7882, 3.0690]], device='cuda:0')
# tensor([[3.0758, 3.2010]], device='cuda:0')
# tensor([[3.3091, 3.7791]], device='cuda:0')
# tensor([[3.1874, 3.6012]], device='cuda:0')
# tensor([[3.5185, 3.7728]], device='cuda:0')
# tensor([[3.9799, 4.0024]], device='cuda:0')
# tensor([[3.4237, 3.5913]], device='cuda:0')
# tensor([[2.9307, 3.0496]], device='cuda:0')
# tensor([[5.5970, 5.1607]], device='cuda:0')
# tensor([[5.7982, 6.4166]], device='cuda:0')
# tensor([[3.3880, 3.1301]], device='cuda:0')
# tensor([[5.9831, 5.5307]], device='cuda:0')
# tensor([[4.5926, 5.0898]], device='cuda:0')
# tensor([[6.8456, 6.5577]], device='cuda:0')
# tensor([[4.4981, 4.7013]], device='cuda:0')
# tensor([[5.0530, 5.2382]], device='cuda:0')
# tensor([[6.4066, 7.0095]], device='cuda:0')
# tensor([[4.6348, 5.0235]], device='cuda:0')
# tensor([[6.1054, 6.3341]], device='cuda:0')
# tensor([[4.9610, 5.5090]], device='cuda:0')
# tensor([[6.3035, 6.6752]], device='cuda:0')
# tensor([[5.2851, 5.9547]], device='cuda:0')
# tensor([[5.6909, 6.2437]], device='cuda:0')
# tensor([[5.3554, 5.8420]], device='cuda:0')
# tensor([[5.6321, 5.8721]], device='cuda:0')
# tensor([[6.5251, 6.9756]], device='cuda:0')
# tensor([[5.1832, 4.9822]], device='cuda:0')
# tensor([[5.4722, 5.6281]], device='cuda:0')
# tensor([[4.7176, 4.7993]], device='cuda:0')
# tensor([[1.1292, 1.1366]], device='cuda:0')
# tensor([[6.1721, 5.7861]], device='cuda:0')
# tensor([[6.1391, 6.2370]], device='cuda:0')
# tensor([[6.1252, 6.3800]], device='cuda:0')
# tensor([[6.4017, 6.3274]], device='cuda:0')
# tensor([[6.0133, 6.1991]], device='cuda:0')
# tensor([[4.8196, 4.9342]], device='cuda:0')
# tensor([[5.8579, 5.9817]], device='cuda:0')
# tensor([[4.9793, 4.7958]], device='cuda:0')
# tensor([[5.7618, 5.8946]], device='cuda:0')
# tensor([[4.8001, 4.9562]], device='cuda:0')
# tensor([[5.1360, 5.3499]], device='cuda:0')
# tensor([[1.2268, 1.2253]], device='cuda:0')
# tensor([[5.7426, 5.9475]], device='cuda:0')
# tensor([[5.2658, 5.3677]], device='cuda:0')
# tensor([[4.8857, 5.1112]], device='cuda:0')
# tensor([[5.7646, 5.9664]], device='cuda:0')
# tensor([[6.0801, 6.3974]], device='cuda:0')
# tensor([[6.0677, 6.2079]], device='cuda:0')
# tensor([[4.5584, 4.9169]], device='cuda:0')
# tensor([[6.0378, 6.1043]], device='cuda:0')
# tensor([[5.5649, 5.5007]], device='cuda:0')
# tensor([[5.2922, 5.2556]], device='cuda:0')
# tensor([[5.5387, 5.8711]], device='cuda:0')
# tensor([[4.9411, 5.1556]], device='cuda:0')
# tensor([[5.1836, 5.8662]], device='cuda:0')
# tensor([[4.1103, 4.4491]], device='cuda:0')
# tensor([[1.3113, 1.3200]], device='cuda:0')
# tensor([[5.2829, 5.6228]], device='cuda:0')
# tensor([[4.7783, 5.4888]], device='cuda:0')
# tensor([[5.8689, 5.9789]], device='cuda:0')
# tensor([[6.5804, 6.5905]], device='cuda:0')
# tensor([[5.2765, 5.0746]], device='cuda:0')
# tensor([[6.0123, 6.0043]], device='cuda:0')
# tensor([[5.0185, 5.1183]], device='cuda:0')
# tensor([[4.9484, 5.2187]], device='cuda:0')
# tensor([[1.2939, 1.2986]], device='cuda:0')
# tensor([[5.7809, 6.2611]], device='cuda:0')
# tensor([[5.6628, 6.1164]], device='cuda:0')
# tensor([[5.8678, 6.2823]], device='cuda:0')
# tensor([[5.4293, 5.6729]], device='cuda:0')
# tensor([[6.0445, 6.2799]], device='cuda:0')
# tensor([[6.5120, 6.7776]], device='cuda:0')
# tensor([[5.5017, 5.8633]], device='cuda:0')
# tensor([[6.0214, 6.2228]], device='cuda:0')
# tensor([[5.3135, 5.5085]], device='cuda:0')
# tensor([[5.3531, 5.7595]], device='cuda:0')
# tensor([[5.8463, 6.4484]], device='cuda:0')
# tensor([[5.6540, 5.9853]], device='cuda:0')
# tensor([[5.6862, 6.2089]], device='cuda:0')
# tensor([[6.1340, 6.4719]], device='cuda:0')
# tensor([[5.4551, 5.8551]], device='cuda:0')
# tensor([[5.6473, 5.6040]], device='cuda:0')
# tensor([[5.6293, 5.9791]], device='cuda:0')
# tensor([[4.3761, 4.3457]], device='cuda:0')
# tensor([[1.4033, 1.4290]], device='cuda:0')
# tensor([[5.3930, 5.7296]], device='cuda:0')
# tensor([[5.4169, 5.9075]], device='cuda:0')
# tensor([[5.2912, 5.7198]], device='cuda:0')
# tensor([[5.8338, 6.2756]], device='cuda:0')
# tensor([[5.5240, 5.7367]], device='cuda:0')
# tensor([[6.2732, 6.4537]], device='cuda:0')
# tensor([[6.0738, 5.9844]], device='cuda:0')
# tensor([[5.4877, 5.6056]], device='cuda:0')
# tensor([[5.2394, 5.3612]], device='cuda:0')
# tensor([[5.1629, 5.8777]], device='cuda:0')
# tensor([[5.4406, 6.1808]], device='cuda:0')
# tensor([[5.9057, 6.1990]], device='cuda:0')
# tensor([[5.8231, 5.8752]], device='cuda:0')
# tensor([[6.6488, 6.7352]], device='cuda:0')
# tensor([[5.9526, 6.4901]], device='cuda:0')
# tensor([[5.4994, 5.7500]], device='cuda:0')
# tensor([[4.0788, 5.1472]], device='cuda:0')
# tensor([[1.3127, 1.3216]], device='cuda:0')
# tensor([[5.1429, 5.5555]], device='cuda:0')
# tensor([[4.2247, 5.1102]], device='cuda:0')
# tensor([[5.7272, 5.7024]], device='cuda:0')
# tensor([[5.8555, 5.9607]], device='cuda:0')
# tensor([[5.4951, 5.6851]], device='cuda:0')
# tensor([[5.5990, 5.7401]], device='cuda:0')
# tensor([[5.3749, 5.4202]], device='cuda:0')
# tensor([[5.3631, 5.7686]], device='cuda:0')
# tensor([[3.5671, 4.4683]], device='cuda:0')
# tensor([[5.2231, 5.5604]], device='cuda:0')
# tensor([[5.3402, 5.6531]], device='cuda:0')
# tensor([[4.3614, 4.4360]], device='cuda:0')
# tensor([[5.4226, 5.6322]], device='cuda:0')
# tensor([[6.0023, 6.3088]], device='cuda:0')
# tensor([[5.9920, 5.8161]], device='cuda:0')
# tensor([[5.0869, 5.2106]], device='cuda:0')
# tensor([[5.2814, 5.3585]], device='cuda:0')
# tensor([[4.9171, 5.2111]], device='cuda:0')
# tensor([[1.3579, 1.3811]], device='cuda:0')
# tensor([[4.9553, 5.9990]], device='cuda:0')
# tensor([[8.2667, 8.6706]], device='cuda:0')
# tensor([[8.9207, 8.8600]], device='cuda:0')
# tensor([[7.6427, 7.7112]], device='cuda:0')
# tensor([[9.2316, 9.5242]], device='cuda:0')
# tensor([[8.2626, 8.1556]], device='cuda:0')
# tensor([[7.1863, 7.2929]], device='cuda:0')
# tensor([[6.1940, 6.1927]], device='cuda:0')
# tensor([[1.9444, 1.9470]], device='cuda:0')
# tensor([[7.5918, 8.1972]], device='cuda:0')
# tensor([[7.7795, 8.1168]], device='cuda:0')
# tensor([[7.5841, 7.9673]], device='cuda:0')
# tensor([[7.9655, 8.1263]], device='cuda:0')
# tensor([[7.9622, 8.1469]], device='cuda:0')
# tensor([[8.1791, 8.3658]], device='cuda:0')
# tensor([[7.6476, 7.8215]], device='cuda:0')
# tensor([[7.4905, 7.5717]], device='cuda:0')
# tensor([[6.7413, 6.8831]], device='cuda:0')
# tensor([[1.8528, 1.8498]], device='cuda:0')
# tensor([[7.6370, 7.7316]], device='cuda:0')
# tensor([[7.7131, 7.9158]], device='cuda:0')
# tensor([[7.2081, 7.6021]], device='cuda:0')
# tensor([[7.6593, 7.9899]], device='cuda:0')
# tensor([[8.0677, 8.4738]], device='cuda:0')
# tensor([[7.1984, 7.2162]], device='cuda:0')
# tensor([[8.4592, 8.7590]], device='cuda:0')
# tensor([[7.1622, 7.0304]], device='cuda:0')
# tensor([[7.8915, 7.9933]], device='cuda:0')
# tensor([[7.4681, 7.2884]], device='cuda:0')
# tensor([[7.4660, 7.4007]], device='cuda:0')
# tensor([[7.2955, 7.3309]], device='cuda:0')
# tensor([[7.0572, 7.2512]], device='cuda:0')
# tensor([[5.2919, 5.6489]], device='cuda:0')
# tensor([[5.6949, 6.2443]], device='cuda:0')
# tensor([[7.6184, 7.9340]], device='cuda:0')
# tensor([[6.2350, 6.1184]], device='cuda:0')
# tensor([[7.1925, 7.8538]], device='cuda:0')
# tensor([[7.1800, 7.3850]], device='cuda:0')
# tensor([[6.6460, 6.8055]], device='cuda:0')
# tensor([[7.6882, 7.8274]], device='cuda:0')
# tensor([[6.6634, 6.6254]], device='cuda:0')
# tensor([[7.7440, 7.9756]], device='cuda:0')
# tensor([[7.1995, 7.1022]], device='cuda:0')
# tensor([[7.1703, 7.1496]], device='cuda:0')
# tensor([[7.8695, 7.8170]], device='cuda:0')
# tensor([[5.5913, 5.8418]], device='cuda:0')
# tensor([[5.6362, 6.1936]], device='cuda:0')
# tensor([[4.8908, 5.4898]], device='cuda:0')
# tensor([[2.2088, 2.3183]], device='cuda:0')
# tensor([[7.2590, 7.2939]], device='cuda:0')
# tensor([[7.9323, 7.9650]], device='cuda:0')
# tensor([[7.6598, 7.5738]], device='cuda:0')
# tensor([[7.1691, 7.1799]], device='cuda:0')
# tensor([[7.8220, 7.7889]], device='cuda:0')
# tensor([[7.4470, 7.2597]], device='cuda:0')
# tensor([[7.1810, 6.9775]], device='cuda:0')
# tensor([[7.1038, 7.3567]], device='cuda:0')
# tensor([[7.5451, 7.7333]], device='cuda:0')
# tensor([[6.1258, 6.4523]], device='cuda:0')
# tensor([[5.4936, 5.5304]], device='cuda:0')
# tensor([[2.0616, 2.0639]], device='cuda:0')
# tensor([[6.9418, 6.7252]], device='cuda:0')
# tensor([[7.3901, 6.9852]], device='cuda:0')
# tensor([[7.2657, 7.2237]], device='cuda:0')
# tensor([[7.1456, 7.3920]], device='cuda:0')
# tensor([[7.4049, 7.5167]], device='cuda:0')
# tensor([[7.1281, 6.6529]], device='cuda:0')
# tensor([[7.5094, 8.0130]], device='cuda:0')
# tensor([[6.9078, 6.8911]], device='cuda:0')
# tensor([[7.9318, 8.0930]], device='cuda:0')
# tensor([[7.1547, 6.6313]], device='cuda:0')
# tensor([[7.6379, 7.6738]], device='cuda:0')
# tensor([[7.4542, 7.4840]], device='cuda:0')
# tensor([[7.5227, 7.9059]], device='cuda:0')
# tensor([[7.6470, 7.7628]], device='cuda:0')
# tensor([[6.7885, 6.0815]], device='cuda:0')
# tensor([[7.9505, 7.5314]], device='cuda:0')
# tensor([[6.9788, 7.4009]], device='cuda:0')
# tensor([[7.6749, 7.5594]], device='cuda:0')
# tensor([[6.8626, 6.6720]], device='cuda:0')
# tensor([[6.4754, 6.3742]], device='cuda:0')
# tensor([[7.8611, 7.8648]], device='cuda:0')
# tensor([[7.4538, 7.3860]], device='cuda:0')
# tensor([[7.4388, 7.5478]], device='cuda:0')
# tensor([[7.7066, 7.2863]], device='cuda:0')
# tensor([[7.4546, 7.5758]], device='cuda:0')
# tensor([[7.2382, 7.2279]], device='cuda:0')
# tensor([[7.5785, 7.6917]], device='cuda:0')
# tensor([[7.4569, 7.1139]], device='cuda:0')
# tensor([[7.9618, 8.0701]], device='cuda:0')
# tensor([[7.5458, 7.0408]], device='cuda:0')
# tensor([[7.8109, 8.0005]], device='cuda:0')
# tensor([[6.5052, 6.7501]], device='cuda:0')
# tensor([[8.0399, 8.4559]], device='cuda:0')
# tensor([[7.0848, 7.3088]], device='cuda:0')
# tensor([[7.3937, 7.4239]], device='cuda:0')
# tensor([[7.7393, 7.5514]], device='cuda:0')
# tensor([[7.4856, 7.3798]], device='cuda:0')
# tensor([[7.6576, 7.3113]], device='cuda:0')
# tensor([[7.7574, 7.6745]], device='cuda:0')
# tensor([[7.6518, 7.6887]], device='cuda:0')
# tensor([[7.6524, 7.7708]], device='cuda:0')
# tensor([[7.9516, 7.9984]], device='cuda:0')
# tensor([[5.6362, 5.9422]], device='cuda:0')
# tensor([[4.7540, 4.4476]], device='cuda:0')
# tensor([[2.2083, 2.2588]], device='cuda:0')
# tensor([[7.3058, 7.4735]], device='cuda:0')
# tensor([[6.6691, 7.4050]], device='cuda:0')
# tensor([[7.9652, 8.0567]], device='cuda:0')
# tensor([[7.4766, 7.6308]], device='cuda:0')
# tensor([[7.5308, 7.8338]], device='cuda:0')
# tensor([[7.0783, 6.8641]], device='cuda:0')
# tensor([[7.2617, 7.2269]], device='cuda:0')
# tensor([[7.1837, 7.3703]], device='cuda:0')
# tensor([[6.6189, 7.1108]], device='cuda:0')
# tensor([[7.0308, 7.5444]], device='cuda:0')
# tensor([[7.0518, 7.5236]], device='cuda:0')
# tensor([[7.0909, 7.0904]], device='cuda:0')
# tensor([[7.2056, 7.8896]], device='cuda:0')
# tensor([[6.5619, 6.9244]], device='cuda:0')
# tensor([[7.7092, 8.0410]], device='cuda:0')
# tensor([[6.8013, 6.9420]], device='cuda:0')
# tensor([[7.8002, 8.0157]], device='cuda:0')
# tensor([[6.2432, 6.2650]], device='cuda:0')
# tensor([[7.7248, 7.8385]], device='cuda:0')
# tensor([[6.7772, 7.2737]], device='cuda:0')
# tensor([[2.2822, 2.3080]], device='cuda:0')
# tensor([[7.3414, 7.5965]], device='cuda:0')
# tensor([[6.4281, 7.2305]], device='cuda:0')
# tensor([[7.5261, 7.5692]], device='cuda:0')
# tensor([[6.4887, 7.0679]], device='cuda:0')
# tensor([[7.2724, 7.7697]], device='cuda:0')
# tensor([[7.1351, 7.2360]], device='cuda:0')
# tensor([[6.9843, 7.1693]], device='cuda:0')
# tensor([[2.4205, 2.4510]], device='cuda:0')
# tensor([[6.7884, 7.3026]], device='cuda:0')
# tensor([[7.7789, 7.9249]], device='cuda:0')
# tensor([[6.5073, 6.8515]], device='cuda:0')
# tensor([[7.1353, 7.5501]], device='cuda:0')
# tensor([[6.8297, 6.8758]], device='cuda:0')
# tensor([[7.1363, 7.2726]], device='cuda:0')
# tensor([[6.9441, 7.0252]], device='cuda:0')
# tensor([[6.7696, 7.0880]], device='cuda:0')
# tensor([[2.3548, 2.3846]], device='cuda:0')
# tensor([[8.8990, 9.0190]], device='cuda:0')
# tensor([[9.2036, 9.5121]], device='cuda:0')
# tensor([[9.1564, 9.5306]], device='cuda:0')
# tensor([[8.9490, 9.0901]], device='cuda:0')
# tensor([[8.2553, 8.5423]], device='cuda:0')
# tensor([[9.1098, 9.6199]], device='cuda:0')
# tensor([[9.0322, 9.2746]], device='cuda:0')
# tensor([[8.7310, 8.3903]], device='cuda:0')
# tensor([[8.6082, 8.9932]], device='cuda:0')
# tensor([[8.7152, 9.1363]], device='cuda:0')
# tensor([[9.3719, 9.6915]], device='cuda:0')
# tensor([[8.1497, 8.5647]], device='cuda:0')
# tensor([[8.6520, 9.3553]], device='cuda:0')
# tensor([[8.8212, 9.4203]], device='cuda:0')
# tensor([[8.8782, 8.9679]], device='cuda:0')
# tensor([[9.0165, 9.1462]], device='cuda:0')
# tensor([[6.4506, 6.5283]], device='cuda:0')
# tensor([[2.9132, 2.9708]], device='cuda:0')
# tensor([[8.5440, 8.6375]], device='cuda:0')
# tensor([[8.9224, 9.3146]], device='cuda:0')
# tensor([[9.0648, 9.2384]], device='cuda:0')
# tensor([[8.3665, 9.0786]], device='cuda:0')
# tensor([[8.7142, 9.0825]], device='cuda:0')
# tensor([[9.6986, 9.9415]], device='cuda:0')
# tensor([[7.8904, 7.9004]], device='cuda:0')
# tensor([[7.5412, 8.2162]], device='cuda:0')
# tensor([[2.7926, 2.8335]], device='cuda:0')
# tensor([[8.5713, 8.2740]], device='cuda:0')
# tensor([[8.5595, 8.9396]], device='cuda:0')
# tensor([[8.3601, 8.5864]], device='cuda:0')
# tensor([[7.4143, 8.4530]], device='cuda:0')
# tensor([[8.2008, 8.8190]], device='cuda:0')
# tensor([[8.5310, 9.3009]], device='cuda:0')
# tensor([[8.1448, 8.5327]], device='cuda:0')
# tensor([[9.0490, 9.1051]], device='cuda:0')
# tensor([[8.7208, 8.9904]], device='cuda:0')
# tensor([[7.9899, 8.1985]], device='cuda:0')
# tensor([[2.8772, 2.9243]], device='cuda:0')
# tensor([[8.8923, 9.2756]], device='cuda:0')
# tensor([[9.2925, 9.0017]], device='cuda:0')
# tensor([[8.4975, 8.7286]], device='cuda:0')
# tensor([[8.2041, 9.1228]], device='cuda:0')
# tensor([[9.3953, 9.6094]], device='cuda:0')
# tensor([[8.5206, 8.7789]], device='cuda:0')
# tensor([[8.3932, 8.8145]], device='cuda:0')
# tensor([[7.2024, 7.9750]], device='cuda:0')
# tensor([[9.0541, 9.3403]], device='cuda:0')
# tensor([[7.2075, 6.9590]], device='cuda:0')
# tensor([[3.2445, 3.2796]], device='cuda:0')
# tensor([[8.4080, 9.4505]], device='cuda:0')
# tensor([[8.7398, 8.8367]], device='cuda:0')
# tensor([[9.2591, 9.3239]], device='cuda:0')
# tensor([[9.1656, 9.3215]], device='cuda:0')
# tensor([[8.6574, 8.9163]], device='cuda:0')
# tensor([[8.2329, 8.6460]], device='cuda:0')
# tensor([[7.9691, 8.3041]], device='cuda:0')
# tensor([[8.9187, 9.1064]], device='cuda:0')
# tensor([[8.7298, 8.6892]], device='cuda:0')
# tensor([[7.5496, 7.6287]], device='cuda:0')
# tensor([[2.8690, 2.9284]], device='cuda:0')
# tensor([[9.3376, 9.8617]], device='cuda:0')
# tensor([[7.7185, 8.6340]], device='cuda:0')
# tensor([[8.1374, 8.5358]], device='cuda:0')
# tensor([[8.8388, 9.0621]], device='cuda:0')
# tensor([[8.9564, 8.9957]], device='cuda:0')
# tensor([[8.0043, 8.1974]], device='cuda:0')
# tensor([[5.3242, 4.7357]], device='cuda:0')
# tensor([[2.7277, 2.8142]], device='cuda:0')
# tensor([[8.9603, 9.1134]], device='cuda:0')
# tensor([[7.4423, 8.5322]], device='cuda:0')
# tensor([[9.2374, 9.4130]], device='cuda:0')
# tensor([[8.2971, 8.6280]], device='cuda:0')
# tensor([[9.1563, 9.5598]], device='cuda:0')
# tensor([[8.2285, 8.3334]], device='cuda:0')
# tensor([[8.9826, 9.7600]], device='cuda:0')
# tensor([[8.0733, 8.5194]], device='cuda:0')
# tensor([[7.6223, 7.2734]], device='cuda:0')
# tensor([[2.8209, 2.8511]], device='cuda:0')
# tensor([[8.1885, 8.3321]], device='cuda:0')
# tensor([[8.0600, 8.9441]], device='cuda:0')
# tensor([[9.0625, 9.2604]], device='cuda:0')
# tensor([[8.7634, 9.2059]], device='cuda:0')
# tensor([[8.5332, 9.0247]], device='cuda:0')
# tensor([[8.5424, 8.7689]], device='cuda:0')
# tensor([[8.6451, 8.8310]], device='cuda:0')
# tensor([[5.5917, 5.1124]], device='cuda:0')
# Complete
